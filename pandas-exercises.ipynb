# %% [markdown]
# # Pandas Practice
#
# This notebook is dedicated to practicing different tasks with pandas.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
#
# Different tasks will be detailed by comments or text.
#
# For further reference and resources, it's advised to check out the [pandas documnetation](https://pandas.pydata.org/pandas-docs/stable/).

# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours

colours_1 = pd.Series(["Red", "Blue" , "Green"])
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
# View the series of different colours
colours_1
# Out:
# pandas.core.series.Series

# %%
# Create a series of three different car types and view it
car_types = pd.Series(["Sports_car", "Convertible", "SUV"])
car_types
# Out:
# 0     Sports_car
# 1    Convertible
# 2            SUV
# dtype: object

# %%
# Combine the Series of cars and colours into a DataFrame

df = pd.DataFrame
df = pd.concat([car_types, colours_1], axis= 1)
df.columns=['Car_Type','Car_Colour']
df
# Out:
#       Car_Type Car_Colour
# 0   Sports_car        Red
# 1  Convertible       Blue
# 2          SUV      Green

# %%
# Import "../data/car-sales-extended.csv" and turn it into a DataFrame
df_car_sales = pd.read_csv('./../../27th feb batch python-20210719T050451Z-001/27th feb batch python/data/car-sales-extended.csv')

# %% [markdown]
# **Note:** Since you've imported `../data/car-sales-extended.csv` as a DataFrame, we'll now refer to this DataFrame as 'the car sales DataFrame'.

# %%
# Export the DataFrame you created to a .csv file
df.to_csv('car_type.csv')

# %%
# Find the different datatypes of the car data DataFrame
df_car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
# Describe your current car sales DataFrame using describe()
df_car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
# Get information about your DataFrame using info()
df_car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# What does it show you?

# %%
# Create a Series of different numbers and find the mean of them
numbers_1 = pd.Series([23,34,90,78,89])
numbers_1.mean()
# Out:
# 62.8

# %%
# Create a Series of different numbers and find the sum of them
numbers_1.sum()
# Out:
# 314

# %%
# List out all the column names of the car sales DataFrame
df_car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find the length of the car sales DataFrame
len(df_car_sales)
# Out:
# 1000

# %%
# Show the first 5 rows of the car sales DataFrame
df_car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
# Show the first 7 rows of the car sales DataFrame
df_car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043
# 5   Honda    Red          42652      4  23883
# 6  Toyota   Blue         163453      4   8473

# %%
# Show the bottom 5 rows of the car sales DataFrame
df_car_sales.tail()
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
df_car_sales.loc[3]
# Out:
# Make             toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
df_car_sales.iloc[3]
# Out:
# Make             toyota
# Colour            White
# Odometer (KM)    154365
# Doors                 4
# Price             13434
# Name: 3, dtype: object

# %% [markdown]
# Notice how they're the same? Why do you think this is?
#
# Check the pandas documentation for [.loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) and [.iloc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html). Think about a different situation each could be used for and try them out.

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
df_car_sales['Odometer (KM)']
# Out:
# 0       35431
# 1      192714
# 2       84714
# 3      154365
# 4      181577
#         ...
# 995     35820
# 996    155144
# 997     66604
# 998    215883
# 999    248360
# Name: Odometer (KM), Length: 1000, dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
df_car_sales['Odometer (KM)'].mean()
# Out:
# 131073.708

# %%
# Select the rows with over 100,000 kilometers on the Odometer
df_car_sales[df_car_sales['Odometer (KM)']> 100000]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 1       bmw   Blue         192714      5  19943
# 3    toyota  White         154365      4  13434
# 4    nissan   Blue         181577      3  14043
# 6    toyota   Blue         163453      4   8473
# 8    nissan  White         130538      4   9374
# ..      ...    ...            ...    ...    ...
# 993  nissan  Black         162523      4   4696
# 994     bmw   Blue         163322      3  31666
# 996  nissan  White         155144      3   5716
# 998   honda  White         215883      4   4001
# 999  toyota   Blue         248360      4  12732
#
# [627 rows x 5 columns]

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(df_car_sales.Make, df_car_sales.Doors)
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
df_car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)     Doors         Price
# Make
# BMW     123540.800000  4.580000  27089.830000
# Honda   124667.671053  4.000000  14514.200658
# Nissan  135480.308081  3.777778  13658.368687
# Toyota  135667.223618  4.000000  15628.160804

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a histogram of the Odometer column using hist()
df_car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
# Try to plot the Price column using plot()
df_car_sales['Price'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Why didn't it work? Can you think of a solution?
#
# You might want to search for "how to convert a pandas string column to numbers".
#
# And if you're still stuck, check out this [Stack Overflow question and answer on turning a price column into integers](https://stackoverflow.com/questions/44469313/price-column-object-to-int-in-pandas).
#
# See how you can provide the example code there to the problem here.

# %%
# Remove the punctuation from price column
df_car_sales[['Price']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   1000 non-null   int64
# dtypes: int64(1)
# memory usage: 7.9 KB

# %%
# Check the changes to the price column

# %%
# Remove the two extra zeros at the end of the price column

# %%
# Check the changes to the Price column

# %%
# Change the datatype of the Price column to integers

# %%
# Lower the strings of the Make column
df_car_sales['Make'].str.lower()
# Out:
# 0       honda
# 1         bmw
# 2       honda
# 3      toyota
# 4      nissan
#         ...
# 995    toyota
# 996    nissan
# 997    nissan
# 998     honda
# 999    toyota
# Name: Make, Length: 1000, dtype: object

# %% [markdown]
# If you check the car sales DataFrame, you'll notice the Make column hasn't been lowered.
#
# How could you make these changes permanent?
#
# Try it out.

# %%
df_car_sales

# %%
# Make lowering the case of the Make column permanent
df_car_sales['Make'] = df_car_sales['Make'].str.lower()

# %%
# Check the car sales DataFrame
df_car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     honda  White          35431      4  15323
# 1       bmw   Blue         192714      5  19943
# 2     honda  White          84714      4  28343
# 3    toyota  White         154365      4  13434
# 4    nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  toyota  Black          35820      4  32042
# 996  nissan  White         155144      3   5716
# 997  nissan   Blue          66604      4  31570
# 998   honda  White         215883      4   4001
# 999  toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# Notice how the Make column stays lowered after reassigning.
#
# Now let's deal with missing data.

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-extended-missing-data")
data_frame = pd.read_csv("./../../27th feb batch python-20210719T050451Z-001/27th feb batch python/data/car-sales-extended-missing-data.csv")

# Check out the new DataFrame
data_frame
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
null_data = data_frame[data_frame.isnull().any(axis=1)]
null_data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 7     Honda  White            NaN    4.0  20306.0
# 8       NaN  White       130538.0    4.0   9374.0
# 13      NaN  White       134181.0    4.0  11121.0
# 20   Toyota    NaN       124844.0    4.0  24130.0
# 21    Honda    NaN        30615.0    4.0  29653.0
# ..      ...    ...            ...    ...      ...
# 974     NaN  White       155383.0    4.0  14345.0
# 975   Honda    NaN        22409.0    4.0  10429.0
# 983  Toyota    Red            NaN    4.0  14671.0
# 985     NaN   Blue       216250.0    4.0   9691.0
# 996     NaN  White       155144.0    3.0   5716.0
#
# [227 rows x 5 columns]

# %% [markdown]
# Notice the missing values are represented as `NaN` in pandas DataFrames.
#
# Let's try fill them.

# %%
# Fill the Odometer (KM) column missing values with the mean of the column inplace
data_frame['Odometer (KM)'].fillna(value=data_frame['Odometer (KM)'].mean(), inplace=True)
data_frame['Odometer (KM)'].isnull().sum()
# Out:
# 0

# %%
# View the car sales missing DataFrame and verify the changes
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  1000 non-null   float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
# Remove the rest of the missing data inplace
data_frame.dropna(inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 815 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           815 non-null    object
#  1   Colour         815 non-null    object
#  2   Odometer (KM)  815 non-null    float64
#  3   Doors          815 non-null    float64
#  4   Price          815 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 38.2+ KB

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
Seats = pd.Series(5).repeat(815)

# %%
data_frame['Seats'] = list(Seats)
data_frame
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
import numpy as np
engine_size = np.linspace(1.3, 4.5, 815)
eng_s = np.random.shuffle(engine_size)

data_frame['Engine_Size'] = engine_size
data_frame
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine_Size
# 0     Honda  White        35431.0    4.0  15323.0      5     1.708845
# 1       BMW   Blue       192714.0    5.0  19943.0      5     1.547666
# 2     Honda  White        84714.0    4.0  28343.0      5     4.444963
# 3    Toyota  White       154365.0    4.0  13434.0      5     3.694103
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     3.128010
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     4.036118
# 995  Toyota  Black        35820.0    4.0  32042.0      5     3.069042
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     2.031204
# 998   Honda  White       215883.0    4.0   4001.0      5     4.040049
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     2.259214
#
# [815 rows x 7 columns]

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
data_frame['Price_of_Car/km'] = ""
data_frame
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine_Size  \
# 0     Honda  White        35431.0    4.0  15323.0      5     1.708845
# 1       BMW   Blue       192714.0    5.0  19943.0      5     1.547666
# 2     Honda  White        84714.0    4.0  28343.0      5     4.444963
# 3    Toyota  White       154365.0    4.0  13434.0      5     3.694103
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     3.128010
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     4.036118
# 995  Toyota  Black        35820.0    4.0  32042.0      5     3.069042
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     2.031204
# 998   Honda  White       215883.0    4.0   4001.0      5     4.040049
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     2.259214
#
#     Price_of_Car/km
# 0
# 1
# 2
# 3
# 4
# ..              ...
# 994
# 995
# 997
# 998
# 999
#
# [815 rows x 8 columns]

# %%
# Remove the last column you added using .drop()
data_frame.drop('Price_of_Car/km',axis=1,inplace=True)
data_frame
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine_Size
# 0     Honda  White        35431.0    4.0  15323.0      5     1.708845
# 1       BMW   Blue       192714.0    5.0  19943.0      5     1.547666
# 2     Honda  White        84714.0    4.0  28343.0      5     4.444963
# 3    Toyota  White       154365.0    4.0  13434.0      5     3.694103
# 4    Nissan   Blue       181577.0    3.0  14043.0      5     3.128010
# ..      ...    ...            ...    ...      ...    ...          ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5     4.036118
# 995  Toyota  Black        35820.0    4.0  32042.0      5     3.069042
# 997  Nissan   Blue        66604.0    4.0  31570.0      5     2.031204
# 998   Honda  White       215883.0    4.0   4001.0      5     4.040049
# 999  Toyota   Blue       248360.0    4.0  12732.0      5     2.259214
#
# [815 rows x 7 columns]

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
df_new_cardata = data_frame.sample(frac=1)
df_new_cardata
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine_Size
# 327     BMW   Blue  130817.000000    3.0  31392.0      5     3.084767
# 326  Toyota   Blue  232912.000000    4.0   6029.0      5     1.716708
# 829   Honda  White  131253.237895    4.0  10130.0      5     4.224816
# 638  Toyota    Red   49807.000000    4.0  25775.0      5     3.835627
# 857     BMW   Blue   31277.000000    5.0  18139.0      5     3.116216
# ..      ...    ...            ...    ...      ...    ...          ...
# 762  Toyota  White  147230.000000    4.0  16645.0      5     3.827764
# 421  Toyota   Blue   81864.000000    4.0  29293.0      5     2.129484
# 348  Toyota  White  117571.000000    4.0  23719.0      5     2.510811
# 140  Nissan   Blue  179666.000000    4.0  19258.0      5     3.650860
# 828  Toyota    Red  220026.000000    4.0   9554.0      5     2.778133
#
# [815 rows x 7 columns]

# %% [markdown]
# Notice how the index numbers get moved around. The [`sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) function is a great way to get random samples from your DataFrame. It's also another great way to shuffle the rows by setting `frac=1`.

# %%
# Reset the indexes of the shuffled DataFrame
df_new_cardata.reset_index(drop=True,inplace=True)
df_new_cardata
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine_Size
# 0       BMW   Blue  130817.000000    3.0  31392.0      5     3.084767
# 1    Toyota   Blue  232912.000000    4.0   6029.0      5     1.716708
# 2     Honda  White  131253.237895    4.0  10130.0      5     4.224816
# 3    Toyota    Red   49807.000000    4.0  25775.0      5     3.835627
# 4       BMW   Blue   31277.000000    5.0  18139.0      5     3.116216
# ..      ...    ...            ...    ...      ...    ...          ...
# 810  Toyota  White  147230.000000    4.0  16645.0      5     3.827764
# 811  Toyota   Blue   81864.000000    4.0  29293.0      5     2.129484
# 812  Toyota  White  117571.000000    4.0  23719.0      5     2.510811
# 813  Nissan   Blue  179666.000000    4.0  19258.0      5     3.650860
# 814  Toyota    Red  220026.000000    4.0   9554.0      5     2.778133
#
# [815 rows x 7 columns]

# %% [markdown]
# Notice the index numbers have been changed to have order (start from 0).

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
df_new_cardata['Odometer (KM)'] = df_new_cardata['Odometer (KM)'].map(lambda x : x*1.6)

# %%
# Change the title of the Odometer (KM) to represent miles instead of kilometers
# df_new_cardata.columns =
df_new_cardata.rename(columns={'Odometer (KM)':'Odometer (MILES)'},inplace=True)
df_new_cardata
# Out:
#        Make Colour  Odometer (MILES)  Doors    Price  Seats  Engine_Size
# 0       BMW   Blue     209307.200000    3.0  31392.0      5     3.084767
# 1    Toyota   Blue     372659.200000    4.0   6029.0      5     1.716708
# 2     Honda  White     210005.180632    4.0  10130.0      5     4.224816
# 3    Toyota    Red      79691.200000    4.0  25775.0      5     3.835627
# 4       BMW   Blue      50043.200000    5.0  18139.0      5     3.116216
# ..      ...    ...               ...    ...      ...    ...          ...
# 810  Toyota  White     235568.000000    4.0  16645.0      5     3.827764
# 811  Toyota   Blue     130982.400000    4.0  29293.0      5     2.129484
# 812  Toyota  White     188113.600000    4.0  23719.0      5     2.510811
# 813  Nissan   Blue     287465.600000    4.0  19258.0      5     3.650860
# 814  Toyota    Red     352041.600000    4.0   9554.0      5     2.778133
#
# [815 rows x 7 columns]

# %% [markdown]
# ## Extensions
#
# For more exercises, check out the pandas documentation, particularly the [10-minutes to pandas section](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html).
#
# One great exercise would be to retype out the entire section into a Jupyter Notebook of your own.
#
# Get hands-on with the code and see what it does.
#
# The next place you should check out are the [top questions and answers on Stack Overflow for pandas](https://stackoverflow.com/questions/tagged/pandas?sort=MostVotes&edited=true). Often, these contain some of the most useful and common pandas functions. Be sure to play around with the different filters!
#
# Finally, always remember, the best way to learn something new to is try it. Make mistakes. Ask questions, get things wrong, take note of the things you do most often. And don't worry if you keep making the same mistake, pandas has many ways to do the same thing and is a big library. So it'll likely take a while before you get the hang of it.
